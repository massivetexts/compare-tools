# %% [markdown]
# # FastText Classification on Metadata

# %%
import fasttext
from SRP import Vector_file
import pandas as pd
import os
import numpy as np
import re
import random
from scipy.spatial.distance import cdist, pdist
import tempfile

meta = pd.read_csv('../../sampling/test_dataset.csv.gz', low_memory=False).set_index('htid').sort_index()

# %% [markdown]
# # Training the models
#
# Multiple models are trained and concatenated together.

# %%
fn, fname = tempfile.mkstemp()

print("Training title string model")
title_enum= meta.title + ' / ' + meta.description.fillna('')
# Writes all the data to a temp filetrains from that file.
with open(fname, mode='w') as f:
    for txt in title_enum:
        f.write(txt+'\n')
titlemodel = fasttext.train_unsupervised(fname, model='skipgram', dim=20)

print("Training clean title string model")
def clean_title(title):
    # Remove up to two trailing '/'-separated sections
    title = title[::-1].split('/', 2)[-1][::-1].strip()
    title = title.split('; by')[0]
    title = re.sub('[\.,;\]\)\[] +?[\(\[]?(assembl|photo|arrang|select|compil|record|collect|edit|translat).{0,100}by.*\.?', '', title, flags=re.IGNORECASE)
    title = re.sub('[\.\,] [bB]y (the .{0,30})?([A-Z]\w+ [A-Z\w+]|author).*\.?', '', title)
    return title
with open(fname, mode='w') as f:
    for txt in meta.title:
        clean = clean_title(txt)
        f.write(clean+'\n')
titlemodel2 = fasttext.train_unsupervised(fname, model='skipgram', dim=40)
        
print("Training truncated title string model")
with open(fname, mode='w') as f:
    for txt in meta.title:
        f.write(txt[:40]+'\n')
titlemodel3 = fasttext.train_unsupervised(fname, model='skipgram', dim=20)
        
print("Training author string model")
with open(fname, mode='w') as f:
    for txt in meta.author:
        f.write(txt+'\n')
authormodel = fasttext.train_unsupervised(fname, model='skipgram', dim=10)

print("Training description string model")
with open(fname, mode='w') as f:
    for txt in meta.description.fillna(' '):
        f.write(txt+'\n')
descmodel = fasttext.train_unsupervised(fname, model='skipgram', dim=10)

os.remove(fname)
# Out:
# Training title string model
# Training clean title string model
# Training truncated title string model
# Training author string model
# Training description string model

# %% [markdown]
# ## Converting metadata to vectors.

# %%
dims = titlemodel.dim + titlemodel2.dim + titlemodel3.dim + authormodel.dim + descmodel.dim

with Vector_file('fastTextVecs.bin', mode='w', dims=dims) as vfile:
    for htid, row in meta.iterrows():
        title =  row['title'] + '/' + row.fillna('')['description']
        author = row['author']
        description = row.fillna(' ')['description']
        fullvec = np.concatenate((titlemodel[title],
                                  titlemodel2[clean_title(row['title'])],
                                  titlemodel3[row['title'][:100]],
                                  authormodel[author],
                                  descmodel[description]))
        vfile.add_row(htid, fullvec)

# %% [markdown]
# # Test Vectors

# %%
with Vector_file('fastTextVecs.bin', mode='r', dims=100) as vfile:
    allvecs = vfile.to_matrix()

# %%
random_targets = np.random.randint(meta.shape[0], size=20)
txts = (meta['title'] + ' | ' + meta['author'] + ' | ' + meta['description'].fillna('')).tolist()

for target_i in random_targets:
        print('TARGET:' + txts[target_i] + '\n' + '=' * 20)
        results = cdist(allvecs['matrix'][target_i:target_i+1], allvecs['matrix'], metric='cosine')
        sorted_results = pd.Series(results[0]).sort_values()

        for i, result in sorted_results.items():
            if result > 0.03:
                break
            name = txts[i]
            print("%.5f\t%s" % (result, name))
        print('\n')
# Out:
# TARGET:The wider outlook beyond the world war, by Charles E. Hooper ... | Hooper, Charles E. |
# ====================
# 0.00000	The wider outlook beyond the world war, by Charles E. Hooper ... | Hooper, Charles E. |
# 0.00000	The wider outlook beyond the world war, by Charles E. Hooper ... | Hooper, Charles E. |
# 0.00589	The wider outlook beyond the World war, by Charles E. Hooper. | Hooper, Charles E. |
# 0.00589	The wider outlook beyond the World war, by Charles E. Hooper. | Hooper, Charles E. |
#
#
# TARGET:Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | 5
# ====================
# 0.00000	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | 5
# 0.00140	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | 4
# 0.00174	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | 7
# 0.00175	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | 6
# 0.00218	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | 2
# 0.00229	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | 10
# 0.00251	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | 3
# 0.00293	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | 8
# 0.00293	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | 17
# 0.00316	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | 16
# 0.00690	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | 21
# 0.01295	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | v.16
# 0.01366	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | v.6
# 0.01497	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | v.13
# 0.01700	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | 13
# 0.02374	Essentials of nematodology. Edited by K.I. Skrjabin. [Translated by Marc Paenson and Z.S. Cole] | Gelʹmintologicheskai︠a︡ laboratorii︠a︡ (Akademii︠a︡ nauk SSSR) | v.4
#
#
# TARGET:Heat conduction; with engineering, geological, and other applications, by Leonard R. Ingersoll, Otto J. Zobel, and Alfred C. Ingersoll | Ingersoll, Leonard Rose, 1880- |
# ====================
# 0.00000	Heat conduction; with engineering, geological, and other applications, by Leonard R. Ingersoll, Otto J. Zobel, and Alfred C. Ingersoll | Ingersoll, Leonard Rose, 1880- |
# 0.00000	Heat conduction; with engineering, geological, and other applications, by Leonard R. Ingersoll, Otto J. Zobel, and Alfred C. Ingersoll | Ingersoll, Leonard Rose, 1880- |
# 0.00000	Heat conduction; with engineering, geological, and other applications, by Leonard R. Ingersoll, Otto J. Zobel, and Alfred C. Ingersoll | Ingersoll, Leonard Rose, 1880- |
# 0.00000	Heat conduction; with engineering, geological, and other applications, by Leonard R. Ingersoll, Otto J. Zobel, and Alfred C. Ingersoll | Ingersoll, Leonard Rose, 1880- |
# 0.00409	Heat conduction : with engineering and geological applications / by Leonard R. Ingersoll, Otto J. Zobel and Alfred C. Ingersoll. | Ingersoll, Leonard Rose, 1880- |
# 0.00409	Heat conduction : with engineering and geological applications / by Leonard R. Ingersoll, Otto J. Zobel and Alfred C. Ingersoll. | Ingersoll, Leonard Rose, 1880- |
# 0.00409	Heat conduction : with engineering and geological applications / by Leonard R. Ingersoll, Otto J. Zobel and Alfred C. Ingersoll. | Ingersoll, Leonard Rose, 1880- |
# 0.02970	An introduction to the mathematical theory of heat conduction : with engineering and geological applications / by L.R. Ingersoll and O.J. Zobel. | Ingersoll, Leonard Rose, 1880- |
# 0.02970	An introduction to the mathematical theory of heat conduction : with engineering and geological applications / by L.R. Ingersoll and O.J. Zobel. | Ingersoll, Leonard Rose, 1880- |
# 0.02970	An introduction to the mathematical theory of heat conduction : with engineering and geological applications / by L.R. Ingersoll and O.J. Zobel. | Ingersoll, Leonard Rose, 1880- |
# 0.02970	An introduction to the mathematical theory of heat conduction : with engineering and geological applications / by L.R. Ingersoll and O.J. Zobel. | Ingersoll, Leonard Rose, 1880- |
# 0.02970	An introduction to the mathematical theory of heat conduction : with engineering and geological applications / by L.R. Ingersoll and O.J. Zobel. | Ingersoll, Leonard Rose, 1880- |
# 0.02970	An introduction to the mathematical theory of heat conduction : with engineering and geological applications / by L.R. Ingersoll and O.J. Zobel. | Ingersoll, Leonard Rose, 1880- |
# 0.02970	An introduction to the mathematical theory of heat conduction : with engineering and geological applications / by L.R. Ingersoll and O.J. Zobel. | Ingersoll, Leonard Rose, 1880- |
# 0.02970	An introduction to the mathematical theory of heat conduction : with engineering and geological applications / by L.R. Ingersoll and O.J. Zobel. | Ingersoll, Leonard Rose, 1880- |
#
#
# TARGET:Cumbriana; or, Fragments of Cumbrian life. By the compiler of the "Glossary of Cumberland words and phrases". | Dickinson, William, 1799?-1882. |
# ====================
# 0.00000	Cumbriana; or, Fragments of Cumbrian life. By the compiler of the "Glossary of Cumberland words and phrases". | Dickinson, William, 1799?-1882. |
# 0.00019	Cumbriana; or, Fragments of Cumbrian life, by the compiler of the "Glossary of Cumberland words and phrases." | Dickinson, William, 1799?-1882. |
# 0.00019	Cumbriana; or, Fragments of Cumbrian life, by the compiler of the "Glossary of Cumberland words and phrases." | Dickinson, William, 1799?-1882. |
#
#
# TARGET:The physical characters of the Indians of southern Mexico, by Frederick Starr. | Starr, Frederick, 1858-1933. |
# ====================
# 0.00000	The physical characters of the Indians of southern Mexico, by Frederick Starr. | Starr, Frederick, 1858-1933. |
# 0.00000	The physical characters of the Indians of southern Mexico, by Frederick Starr. | Starr, Frederick, 1858-1933. |
# 0.00000	The physical characters of the Indians of southern Mexico, by Frederick Starr. | Starr, Frederick, 1858-1933. |
# 0.00000	The physical characters of the Indians of southern Mexico, by Frederick Starr. | Starr, Frederick, 1858-1933. |
# 0.00000	The physical characters of the Indians of southern Mexico, by Frederick Starr. | Starr, Frederick, 1858-1933. |
# 0.00007	The physical characters of the Indians of southern Mexico / by Frederick Starr. | Starr, Frederick, 1858-1933. |
#
#
# TARGET:Issues in social science. | Weinberg, Meyer, 1920- |
# ====================
# 0.00000	Issues in social science. | Weinberg, Meyer, 1920- |
#
#
# TARGET:Merchant shipping act, 1894. Official notices, issued by the Board of trade, with regard to rules and regulations conditionally approved under Section 453 of the Act. | Great Britain. Board of Trade |
# ====================
# 0.00000	Merchant shipping act, 1894. Official notices, issued by the Board of trade, with regard to rules and regulations conditionally approved under Section 453 of the Act. | Great Britain. Board of Trade |
# 0.02573	Particulars of dealers in securities and of unit trusts, 1969 : published under the Prevention of Fraud (Investments) Act 1958 | Great Britain. Board of Trade |
# 0.02724	Cost of living in German towns. Report of an inquiry by the Board of trade into working class rents, housing and retail prices, together with the rates of wages in certain occupations in the principal industrial towns of the German Empire. With an introductory memorandum and a comparison of conditions in Germany and the United Kingdom. Presented to both houses of Parliament by command of His Majesty. | Great Britain. Board of Trade |
# 0.02724	Cost of living in German towns. Report of an inquiry by the Board of trade into working class rents, housing and retail prices, together with the rates of wages in certain occupations in the principal industrial towns of the German Empire. With an introductory memorandum and a comparison of conditions in Germany and the United Kingdom. Presented to both houses of Parliament by command of His Majesty. | Great Britain. Board of Trade |
# 0.02937	Wholesale and retail prices. Return to an order of the ... House of commons, dated 6th August, 1903: -- for "Report on wholesale and retail prices in the United Kingdom in 1902, with comparative statistical tables for a series of years" ... Ordered, by the House of commons, to be printed, 6th August 1903. | Great Britain. Board of Trade |
# 0.02937	Wholesale and retail prices. Return to an order of the ... House of commons, dated 6th August, 1903: -- for "Report on wholesale and retail prices in the United Kingdom in 1902, with comparative statistical tables for a series of years" ... Ordered, by the House of commons, to be printed, 6th August 1903. | Great Britain. Board of Trade |
# 0.02937	Wholesale and retail prices. Return to an order of the ... House of commons, dated 6th August, 1903: -- for "Report on wholesale and retail prices in the United Kingdom in 1902, with comparative statistical tables for a series of years" ... Ordered, by the House of commons, to be printed, 6th August 1903. | Great Britain. Board of Trade |
# 0.02937	Wholesale and retail prices. Return to an order of the ... House of commons, dated 6th August, 1903: -- for "Report on wholesale and retail prices in the United Kingdom in 1902, with comparative statistical tables for a series of years" ... Ordered, by the House of commons, to be printed, 6th August 1903. | Great Britain. Board of Trade |
#
#
# TARGET:Human origins; a manual of prehistory. | MacCurdy, George Grant, 1863-1947. | v.2
# ====================
# 0.00000	Human origins; a manual of prehistory. | MacCurdy, George Grant, 1863-1947. | v.2
# 0.00000	Human origins; a manual of prehistory. | MacCurdy, George Grant, 1863-1947. | v.2
# 0.00047	Human origins; a manual of prehistory. | MacCurdy, George Grant, 1863-1947. | v.1
# 0.00047	Human origins; a manual of prehistory. | MacCurdy, George Grant, 1863-1947. | v.1
# 0.00047	Human origins; a manual of prehistory. | MacCurdy, George Grant, 1863-1947. | v.1
# 0.01825	Human origins; a manual of prehistory, by George Grant MacCurdy. | MacCurdy, George Grant, 1863-1947. | v.2
# 0.01893	Human origins; a manual of prehistory, by George Grant MacCurdy. | MacCurdy, George Grant, 1863-1947. | v.1
# 0.02225	Human origins; a manual of prehistory, by George Grant MacCurdy ... | MacCurdy, George Grant, 1863-1947. | v.1
#
#
# TARGET:Africa: classification schedule. | Harvard University. Library. |
# ====================
# 0.00000	Africa: classification schedule. | Harvard University. Library. |
#
#
# TARGET:Mysticism and the experience of love / by Howard Thurman. -- | Thurman, Howard, 1900-1981. |
# ====================
# 0.00000	Mysticism and the experience of love / by Howard Thurman. -- | Thurman, Howard, 1900-1981. |
#
#
# TARGET:A history of dancing. By Reginald St. Johnston ... | St.-Johnston, Reginald, Sir, 1881-1950. |
# ====================
# 0.00000	A history of dancing. By Reginald St. Johnston ... | St.-Johnston, Reginald, Sir, 1881-1950. |
# 0.00000	A history of dancing. By Reginald St. Johnston ... | St.-Johnston, Reginald, Sir, 1881-1950. |
# 0.00455	A history of dancing / Reginald St. Johnston. | St.-Johnston, Reginald, Sir, 1881-1950. |
#
#
# TARGET:A shoulder to the wheel of progress : being essays, lectures and miscellaneous upon themes of the day / by Wm. Maxwell Wood. | Wood, William Maxwell, 1809-1880. |
# ====================
# 0.00000	A shoulder to the wheel of progress : being essays, lectures and miscellaneous upon themes of the day / by Wm. Maxwell Wood. | Wood, William Maxwell, 1809-1880. |
# 0.00000	A shoulder to the wheel of progress : being essays, lectures and miscellaneous upon themes of the day / by Wm. Maxwell Wood. | Wood, William Maxwell, 1809-1880. |
# 0.00000	A shoulder to the wheel of progress : being essays, lectures and miscellaneous upon themes of the day / by Wm. Maxwell Wood. | Wood, William Maxwell, 1809-1880. |
#
#
# TARGET:Some first steps in human progress. | Starr, Frederick, 1858-1933. |
# ====================
# 0.00000	Some first steps in human progress. | Starr, Frederick, 1858-1933. |
# 0.01665	Some first steps in human progress / by Frederick Starr ... | Starr, Frederick, 1858-1933. |
# 0.01759	Some first steps in human progress / by Frederick Starr. | Starr, Frederick, 1858-1933. |
# 0.01759	Some first steps in human progress / by Frederick Starr. | Starr, Frederick, 1858-1933. |
# 0.01759	Some first steps in human progress / by Frederick Starr. | Starr, Frederick, 1858-1933. |
#
#
# TARGET:Proverbial philosophy: a book of thoughts and arguments. 1st and 2d ser. | Tupper, Martin Farquhar, 1810-1889. |
# ====================
# 0.00000	Proverbial philosophy: a book of thoughts and arguments. 1st and 2d ser. | Tupper, Martin Farquhar, 1810-1889. |
# 0.00438	Proverbial philosophy; a book of thoughts and arguments. 1st and 2d series in one volume. | Tupper, Martin Farquhar, 1810-1889. |
# 0.00686	Proverbial philosophy: a book of thoughts and arguments. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01227	Proverbial philosophy: a book of thoughts and arguments, | Tupper, Martin Farquhar, 1810-1889. |
# 0.01249	Proverbial philosophy : a book of thoughts and arguments, originally treated. First and second series. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01324	Proverbial philosophy : a book of thoughts and arguments, originally treated, first series ; Proverbial philosophy : a book of thoughts and arguments, originally treated, second series / by Martin Farquhar Tupper. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01362	Proverbial philosophy : a book of thoughts and arguments / originally treated by Martin Farquhar Tupper. | Tupper, Martin Farquhar, 1810-1889. | ---
# 0.01368	Proverbial philosophy : a book of thoughts and arguments originaly treated / by Martin Farquhar Tupper. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01454	Proverbial philosophy : a book of thoughts and arguments, originally treated : first [-second] series / by Martin Farquhar Tupper. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01541	Proverbial philosophy : a book of thoughts and arguments, originally treated : first and second series, complete in one volume / by Martin Farquhar Tupper. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01565	Proverbial philosophy: a book of thoughts and arguments, originally treated by Martin Farquhar Tupper ... First [-second] series. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01565	Proverbial philosophy: a book of thoughts and arguments, originally treated by Martin Farquhar Tupper ... First [-second] series. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01585	Proverbial philosophy; a book of thoughts and arguments, originally treated. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01585	Proverbial philosophy; a book of thoughts and arguments, originally treated. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01662	Proverbial philosophy: a book of thoughts and arguments, originally treated by Martin Farquhar Tupper ... First [-second] series. | Tupper, Martin Farquhar, 1810-1889. | ---
# 0.01693	Proverbial philosophy : a book of thoughts and arguments, originally treated. Second series, from the fifth London edition. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01714	Proverbial philosophy : a book of thoughts and arguments, originally treated / by Martin Farquhar Tupper. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01714	Proverbial philosophy : a book of thoughts and arguments, originally treated / by Martin Farquhar Tupper. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01714	Proverbial philosophy : a book of thoughts and arguments, originally treated / by Martin Farquhar Tupper. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01714	Proverbial philosophy : a book of thoughts and arguments, originally treated / by Martin Farquhar Tupper. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01825	Tupper's proverbial philosophy : a book of thoughts and arguments, originally treated / by Martin Farquhar Tupper ; first and second series. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01875	Tupper's Proverbial philosophy: a book of thoughts and arguments, originally treated. Also, A thousand lines, and other poems ... From the London ed. | Tupper, Martin Farquhar, 1810-1889. |
# 0.01982	Tupper's Proverbial philosophy : a book of thoughts and arguments, originally treated. Also, A thousand lines, and other poems / by Martin Farquhar Tupper. | Tupper, Martin Farquhar, 1810-1889. | ---
# 0.02449	A third series of proverbial philosophy: | Tupper, Martin Farquhar, 1810-1889. |
# 0.02590	Proverbial philosophy ; A modern pyramid ; and the poems of King Alfred / by Martin Farquhar Tupper. | Tupper, Martin Farquhar, 1810-1889. |
#
#
# TARGET:The anatomy of the lymphatic system. | Klein, E. 1844-1925. | 1873 [v.1]
# ====================
# 0.00000	The anatomy of the lymphatic system. | Klein, E. 1844-1925. | 1873 [v.1]
#
#
# TARGET:In our town, by William Allen White; illustrations by F.R.Gruger and W. Glackens. | White, William Allen, 1868-1944. |
# ====================
# 0.00000	In our town, by William Allen White; illustrations by F.R.Gruger and W. Glackens. | White, William Allen, 1868-1944. |
# 0.00034	In our town / by William Allen White ; illustrations by F.R. Gruger and W. Glackens. | White, William Allen, 1868-1944. |
# 0.00053	In our town / by William Allen White; illustrations by F. R. Gruger and W. Glackens. | White, William Allen, 1868-1944. |
# 0.00060	In our town, by William Allen White. Illustrations by F.R. Gruger and W. Glackens. | White, William Allen, 1868-1944. |
# 0.00060	In our town, by William Allen White. Illustrations by F.R. Gruger and W. Glackens. | White, William Allen, 1868-1944. |
# 0.01296	In our town / by William Allen White ; illustrated by F.R. Gruger and W. Glackens. | White, William Allen, 1868-1944. |
#
#
# TARGET:Christianity and Western civilization. | Hayes, Carlton J. H. 1882-1964 |
# ====================
# 0.00000	Christianity and Western civilization. | Hayes, Carlton J. H. 1882-1964 |
# 0.00000	Christianity and Western civilization. | Hayes, Carlton J. H. 1882-1964 |
# 0.00000	Christianity and Western civilization. | Hayes, Carlton J. H. 1882-1964 |
#
#
# TARGET:After noon, by Suzan Ertz. | Ertz, Susan. |
# ====================
# 0.00000	After noon, by Suzan Ertz. | Ertz, Susan. |
# 0.00000	After noon, by Suzan Ertz. | Ertz, Susan. |
#
#
# TARGET:The path to Rome, by H. Belloc ... | Belloc, Hilaire, 1870-1953. |
# ====================
# 0.00000	The path to Rome, by H. Belloc ... | Belloc, Hilaire, 1870-1953. |
# 0.00000	The path to Rome, by H. Belloc ... | Belloc, Hilaire, 1870-1953. |
# 0.00134	The path to Rome, by H. Belloc. | Belloc, Hilaire, 1870-1953. |
# 0.01668	This and that and the other, by H. Belloc ... | Belloc, Hilaire, 1870-1953. |
# 0.01700	The four men; a farrago, by H. Belloc. | Belloc, Hilaire, 1870-1953. |
# 0.01781	The four men; a farrago [by] Hilaire Belloc .... | Belloc, Hilaire, 1870-1953. |
# 0.01848	This and that and the other, by H. Belloc... | Belloc, Hilaire, 1870-1953. |
# 0.01848	This and that and the other, by H. Belloc... | Belloc, Hilaire, 1870-1953. |
# 0.01973	The path to Rome. | Belloc, Hilaire, 1870-1953. |
# 0.02087	The mercy of Allah, by Hilaire Belloc. | Belloc, Hilaire, 1870-1953. |
# 0.02161	Robespierre, a study by Hilaire Belloc. | Belloc, Hilaire, 1870-1953. |
# 0.02371	The verse of Hilaire Belloc / edited by W.N. Roughead. | Belloc, Hilaire, 1870-1953. |
# 0.02453	The Hilaire Belloc calendar : a quotation from the works of Hilaire Belloc for every day in the year. | Belloc, Hilaire, 1870-1953. |
# 0.02514	Pongo and the bull / H. Belloc. | Belloc, Hilaire, 1870-1953. |
# 0.02532	Emmanuel Burden, merchant, of Thames St., in the city of London, exporter of hardware; a record of his lineage, speculations, last days, and death, by Hilaire Belloc; with thirty-four illustrations by G. K. Chesterton. | Belloc, Hilaire, 1870-1953. |
# 0.02605	The aftermath = or, Gleanings from a busy life : called upon the outer cover for purposes of sale, Caliban's guide to letters / by H.B. | Belloc, Hilaire, 1870-1953. |
# 0.02610	The mercy of Allah, | Belloc, Hilaire, 1870-1953. |
# 0.02648	The four men: a farrago / [by] Hilaire Belloc. | Belloc, Hilaire, 1870-1953. | ---
# 0.02679	The aftermath ; or, Gleanings from a busy life. Called upon the outer cover for purposes of sale, Calibans̓ guide to letters. by H. B. | Belloc, Hilaire, 1870-1953. |
# 0.02960	The mercy of Allah. | Belloc, Hilaire, 1870-1953. |
#
#
# TARGET:The North American species of Drosophila, by A. H. Sturtevant. | Sturtevant, A. H. 1891-1970. |
# ====================
# 0.00000	The North American species of Drosophila, by A. H. Sturtevant. | Sturtevant, A. H. 1891-1970. |
# 0.00000	The North American species of Drosophila, by A. H. Sturtevant. | Sturtevant, A. H. 1891-1970. |
# 0.00000	The North American species of Drosophila, by A. H. Sturtevant. | Sturtevant, A. H. 1891-1970. |
